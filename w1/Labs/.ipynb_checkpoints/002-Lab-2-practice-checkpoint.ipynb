# %% [markdown]
# # Lab 2: Arithmetic Operators
#
# ## Introduction
# This lab is designed to develop the understanding of students with Python input and arithmetic operations, along with the use of variables and making use of the conditional statements.
#
# ## Objectives
# In this lab, the students will learn about:
# - User input
# - Arithmetic operations
# - Use of variables
# - Conditional statements in Python
#
# ## Tools/Software Requirement
# - Jupyter Notebook (Python)
#
# ## Arithmetic Operators
#
# The Python interpreter can be used to express the arithmetic operators in a very simple way as described below:
#
# ```python
# # For Addition
# print(1 + 1) # Output: 2
#
# # For Multiplication
# print(2 * 3) # Output: 6
#
# # For Integer Division
# print(17 // 10) # Output: 1
# print(-17 // 10) # Output: -2
#
# # For Modulus
# print(27 % 10) # Output: 7
# print(-27 % 10) # Output: 3
# ```

# %%
# Excercise 1
# For each of the following expressions, what value will the expression give? Verify your answers by typing the expressions into Python.

# a.9 - 3
# b.8 * 2.5
# c.9 / 2
# d.9 / -2
# e.9 // -2
# f.9 % 2
# g.9.0 % 2
# h.9 % 2.0
# i.9 % -2
# j.-9 % 2
# k.9 / -2.0


# Solution 
print(9 - 3)
print(8 * 2.5)
print(9 / 2)
print(9 / -2)
print(9 // -2)
print(9 % 2)
print(9.0 % 2)
print(9 % 2.0)
print(9 % -2)
print(-9 % 2)
print(9 / -2.0)
# Out:
# 6
# 20.0
# 4.5
# -4.5
# -5
# 1
# 1.0
# 1.0
# -1
# 1
# -4.5

# %% [markdown]
# ## Variables
#
# ``` python
# >>> length= 22.0
# >>> width= 5.0
# >>> Area= length *width
# >>> Area
# 110.0
#
# #Variables are called variables because their values can vary as the program executes. We can assign a new value to a variable:
# >>> degrees_celsius = 26.0
# >>> 9 / 5 * degrees_celsius + 32
# 78.80000000000001
# >>> degrees_celsius = 0.0
# >>> 9 / 5 * degrees_celsius + 32
# 32.0
# >>> difference = 20
# >>> double = 2 * difference
# >>> double
# 40

# %%
# Excercise 2
# ●Create a variable x that stores an integer. Print out x, 2x, 3x, 4x, and 5x, each separated by three dashes, like below if x=7. (hint: use multiplication operator and print function)

# 	7---14---21---28---35	

x=7
print(f"{x}---{x*2}---{x*3}---{x*4}---{x*5}")
# Out:
# 7---14---21---28---35

# %% [markdown]
# ## Taking Input in Python
# ``` python
# num = int(input("Enter a number: "))
# print(num, " ", type(num))
# floatNum = float(input("Enter a decimal number: "))
# print(floatNum, " ", type(floatNum))
# ```
# Output:
# ![image.png](attachment:0d35b699-83fd-4400-84f8-35b7c3ca635f.png)

# %% [markdown]
# #### Write a program that asks the user to enter two numbers, obtains the two numbers from the user and prints the sum, product, difference, quotient and remainder of the two numbers. Sample output is as following:

# %%
num1 = int(input("Enter First Number : "))
num2 = int(input("Enter Second Number : "))
print ("sum =", num1 + num2, "\nproduct =", num1*num2, "\ndifference =", num1 - num2, "\nquotient =", num1/num2, "\nreminder =", num1%num2)
# Out:
# Enter First Number :  20
# Enter Second Number :  50
# sum = 70
# product = 1000
# difference = -30
# quotient = 0.4
# reminder = 20

# %% [markdown]
# #### Write a program that reads in the radius of a circle and prints the circle’s diameter, circumference and area. Use the constant value 3.14159 for π. Perform each of these calculations inside the print statement().

# %%
radius = float(input("Enter Radius Of the Circle : "))
pi = 3.14159
print("Diameter =",radius*2, "\nCircumference =", 2*pi*radius, "\nArea =", pi*(radius**2))
# Out:
# Enter Radius Of the Circle :  6
# Diameter = 12.0
# Circumference = 37.699079999999995
# Area = 113.09724

# %% [markdown]
# #### Write a program that produces the following output using variables instead of hardcoding:
# ```
# #####
#  ####
#   ###
#    ##
#     #

# %%
#using variable and without hardcoding
var1 = "#"
print(var1+var1+var1+var1+var1)
print(" "+var1+var1+var1+var1)
print("  "+var1+var1+var1)
print("   "+var1+var1)
print("    "+var1)
# Out:
# #####
#  ####
#   ###
#    ##
#     #
