# %%
from math import sqrt,factorial,pi,,gcd
print(math.sqrt(159))
# Out:
#   Cell In[29], line 1
#     from math import sqrt,factorial,pi,,gcd
#                                        ^
# SyntaxError: invalid syntax

# %%
factorial(10)
# Out:
# 3628800

# %%
sqrt(159),sqrt(15)
# Out:
# (12.609520212918492, 3.872983346207417)

# %%
factorial(1000)
# Out:
# ...

# %%
area_of_square = pi*(pow(7,2))
print(area_of_square)
# Out:
# 153.93804002589985

# %%
import math
print(math.gcd(400, 40))
# Out:
# 40

# %%
math.ceil(5.87)
# Out:
# 6

# %%
math.floor(5.18)
# Out:
# 5

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 math.abs(12)
#
# AttributeError: module 'math' has no attribute 'abs'

# %%
import random

# %%
random.random()
# Out:
# 0.053250088884044144

# %%
random.randint(20,30)
# Out:
# 22

# %%
random.uniform(0.5,5.78)
# Out:
# 1.6451360189662714

# %%
help(random)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/random.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#         bytes
#         -----
#                uniform bytes (values between 0 and 255)
#
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
# ...

# %%
dise_roll = random.randint(1,6)
print(dise_roll)
# Out:
# 4

# %%
list = [i for i in range(1,100)]
random.choice(list)
# Out:
# 95

# %%
random.shuffle(list)
print(list)
# Out:
# [69, 61, 9, 22, 39, 40, 45, 60, 85, 95, 17, 67, 84, 16, 83, 74, 96, 92, 14, 28, 78, 75, 31, 81, 6, 36, 99, 44, 1, 65, 43, 66, 82, 86, 89, 20, 10, 70, 79, 41, 54, 11, 2, 72, 42, 32, 71, 58, 53, 48, 62, 5, 59, 94, 12, 37, 63, 49, 18, 34, 97, 8, 23, 68, 46, 90, 76, 3, 38, 26, 87, 29, 73, 27, 4, 24, 25, 57, 33, 51, 91, 98, 35, 93, 21, 13, 30, 52, 19, 47, 77, 50, 56, 88, 7, 15, 64, 80, 55]

# %%
u_r_n = random.sample(range(1,100),20)
print(u_r_n)
# Out:
# [2, 21, 16, 58, 63, 46, 71, 62, 65, 98, 47, 37, 56, 22, 92, 4, 77, 85, 15, 69]
